# %%
import pandas as pd
data = [
    {
        'price': 250000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Suburban',
        'year_built': 1995,
    },
    {
        'price': 350000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2000,
    },
    {
        'price': 420000,
        'sqft': 2600,
        'bedrooms': 4,
        'bathrooms': 3.5,
        'neighborhood': 'Suburban',
        'year_built': 2010,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1980,
    },
    {
        'price': 320000,
        'sqft': 2000,
        'bedrooms': 4,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1998,
    },
    {
        'price': 450000,
        'sqft': 2800,
        'bedrooms': 5,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2005,
    },
    {
        'price': 380000,
        'sqft': 2400,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 2002,
    },
    {
        'price': 300000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Urban',
        'year_built': 1992,
    },
    {
        'price': 270000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1975,
    },
    {
        'price': 360000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2001,
    },
    {
        'price': 410000,
        'sqft': 2500,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2012,
    },
    {
        'price': 290000,
        'sqft': 1700,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1996,
    },
    {
        'price': 240000,
        'sqft': 1500,
        'bedrooms': 2,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1985,
    },
    {
        'price': 320000,
        'sqft': 1900,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 1999,
    },
    {
        'price': 370000,
        'sqft': 2300,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2003,
    },
    {
        'price': 260000,
        'sqft': 1700,
        'bedrooms': 2,
        'bathrooms': 1.5,
        'neighborhood': 'Rural',
        'year_built': 1978,
    },
    {
        'price': 335000,
        'sqft': 2100,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 2007,
    },
    {
        'price': 310000,
        'sqft': 2000,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood':"Surburban",
        'year_built': 1997,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1983,
    },
    {
        'price': 400000,
        'sqft': 2500,
        'bedrooms':7, 
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2015,
    }
    
]
res = pd.DataFrame(data)
res
# Out:
#      price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0   250000  1800         3        2.0     Suburban        1995
# 1   350000  2200         4        3.0        Urban        2000
# 2   420000  2600         4        3.5     Suburban        2010
# 3   280000  1600         3        2.0        Rural        1980
# 4   320000  2000         4        2.5     Suburban        1998
# 5   450000  2800         5        3.0        Urban        2005
# 6   380000  2400         3        2.5     Suburban        2002
# 7   300000  1800         3        2.0        Urban        1992
# 8   270000  1600         3        2.0        Rural        1975
# 9   360000  2200         4        3.0     Suburban        2001
# 10  410000  2500         4        3.0        Urban        2012
# 11  290000  1700         3        2.5     Suburban        1996
# 12  240000  1500         2        2.0        Rural        1985
# 13  320000  1900         3        2.5        Urban        1999
# ...

# %%
display(res.head())
# Out:
#     price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0  250000  1800         3        2.0     Suburban        1995
# 1  350000  2200         4        3.0        Urban        2000
# 2  420000  2600         4        3.5     Suburban        2010
# 3  280000  1600         3        2.0        Rural        1980
# 4  320000  2000         4        2.5     Suburban        1998

# %%
display(res.describe())
# Out:
#                price         sqft   bedrooms  bathrooms   year_built
# count      20.000000    20.000000  20.000000  20.000000    20.000000
# mean   329750.000000  2040.000000   3.500000   2.475000  1996.650000
# std     60837.899372   384.433965   1.100239   0.525031    11.412251
# min    240000.000000  1500.000000   2.000000   1.500000  1975.000000
# 25%    280000.000000  1700.000000   3.000000   2.000000  1990.250000
# 50%    320000.000000  2000.000000   3.000000   2.500000  1998.500000
# 75%    372500.000000  2325.000000   4.000000   3.000000  2003.500000
# max    450000.000000  2800.000000   7.000000   3.500000  2015.000000

# %%
display(res.isnull().sum())
# Out:
# price           0
# sqft            0
# bedrooms        0
# bathrooms       0
# neighborhood    0
# year_built      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
plt.figure(figsize=(8,6))
sns.histplot(res["price"],bins=20,kde=True)
plt.title("Histogram of House price")
plt.xlabel("price")
plt.ylabel("count")
plt.show()

# %%
import pandas as pd
data = [ {
        'price': 250000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Suburban',
        'year_built': 1995,
    },
    {
        'price': 350000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2000,
    },
    {
        'price': 420000,
        'sqft': 2600,
        'bedrooms': 4,
        'bathrooms': 3.5,
        'neighborhood': 'Suburban',
        'year_built': 2010,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1980,
    },
    {
        'price': 320000,
        'sqft': 2000,
        'bedrooms': 4,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1998,
    },
    {
        'price': 450000,
        'sqft': 2800,
        'bedrooms': 5,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2005,
    },
    {
        'price': 380000,
        'sqft': 2400,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 2002,
    },
    {
        'price': 300000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Urban',
        'year_built': 1992,
    },
    {
        'price': 270000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1975,
    },
    {
        'price': 360000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2001,
    },
    {
        'price': 410000,
        'sqft': 2500,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2012,
    },
    {
        'price': 290000,
        'sqft': 1700,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1996,
    },
    {
        'price': 240000,
        'sqft': 1500,
        'bedrooms': 2,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1985,
    },
    {
        'price': 320000,
        'sqft': 1900,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 1999,
    },
    {
        'price': 370000,
        'sqft': 2300,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2003,
    },
    {
        'price': 260000,
        'sqft': 1700,
        'bedrooms': 2,
        'bathrooms': 1.5,
        'neighborhood': 'Rural',
        'year_built': 1978,
    },
    {
        'price': 335000,
        'sqft': 2100,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 2007,
    },
    {
        'price': 310000,
        'sqft': 2000,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood':"Surburban",
        'year_built': 1997,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1983,
    },
    {
        'price': 400000,
        'sqft': 2500,
        'bedrooms':7, 
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2015,
    }]
res = pd.DataFrame(data)
res
# Out:
#      price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0   250000  1800         3        2.0     Suburban        1995
# 1   350000  2200         4        3.0        Urban        2000
# 2   420000  2600         4        3.5     Suburban        2010
# 3   280000  1600         3        2.0        Rural        1980
# 4   320000  2000         4        2.5     Suburban        1998
# 5   450000  2800         5        3.0        Urban        2005
# 6   380000  2400         3        2.5     Suburban        2002
# 7   300000  1800         3        2.0        Urban        1992
# 8   270000  1600         3        2.0        Rural        1975
# 9   360000  2200         4        3.0     Suburban        2001
# 10  410000  2500         4        3.0        Urban        2012
# 11  290000  1700         3        2.5     Suburban        1996
# 12  240000  1500         2        2.0        Rural        1985
# 13  320000  1900         3        2.5        Urban        1999
# ...

# %%
display(res.head())
# Out:
#     price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0  250000  1800         3        2.0     Suburban        1995
# 1  350000  2200         4        3.0        Urban        2000
# 2  420000  2600         4        3.5     Suburban        2010
# 3  280000  1600         3        2.0        Rural        1980
# 4  320000  2000         4        2.5     Suburban        1998

# %%
display(res.describe())
# Out:
#                price         sqft   bedrooms  bathrooms   year_built
# count      20.000000    20.000000  20.000000  20.000000    20.000000
# mean   329750.000000  2040.000000   3.500000   2.475000  1996.650000
# std     60837.899372   384.433965   1.100239   0.525031    11.412251
# min    240000.000000  1500.000000   2.000000   1.500000  1975.000000
# 25%    280000.000000  1700.000000   3.000000   2.000000  1990.250000
# 50%    320000.000000  2000.000000   3.000000   2.500000  1998.500000
# 75%    372500.000000  2325.000000   4.000000   3.000000  2003.500000
# max    450000.000000  2800.000000   7.000000   3.500000  2015.000000

# %%
display(res.tail())
# Out:
#      price  sqft  bedrooms  bathrooms neighborhood  year_built
# 15  260000  1700         2        1.5        Rural        1978
# 16  335000  2100         3        2.5        Urban        2007
# 17  310000  2000         3        2.0    Surburban        1997
# 18  280000  1600         3        2.0        Rural        1983
# 19  400000  2500         7        3.0        Urban        2015

# %%
missingv = res.isna()
display(missingv)
# Out:
#     price   sqft  bedrooms  bathrooms  neighborhood  year_built
# 0   False  False     False      False         False       False
# 1   False  False     False      False         False       False
# 2   False  False     False      False         False       False
# 3   False  False     False      False         False       False
# 4   False  False     False      False         False       False
# 5   False  False     False      False         False       False
# 6   False  False     False      False         False       False
# 7   False  False     False      False         False       False
# 8   False  False     False      False         False       False
# 9   False  False     False      False         False       False
# 10  False  False     False      False         False       False
# 11  False  False     False      False         False       False
# 12  False  False     False      False         False       False
# 13  False  False     False      False         False       False
# ...

# %%
missingvc = missingv.sum()
display(missingvc)
# Out:
# price           0
# sqft            0
# bedrooms        0
# bathrooms       0
# neighborhood    0
# year_built      0
# dtype: int64

# %%
totalmissing = missingvc.sum()
print(totalmissing)
# Out:
# 0

# %%
display(res.isna().sum())
# Out:
# price           0
# sqft            0
# bedrooms        0
# bathrooms       0
# neighborhood    0
# year_built      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
plt.figure(figsize=(8,2))
sns.histplot(res["price"],bins=20,kde=True)
plt.title("Histogram of the house price")
plt.xlabel("price")
plt.ylabel("count")
plt.show()

# %%
import pandas as pd
data = [ {
        'price': 250000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Suburban',
        'year_built': 1995,
    },
    {
        'price': 350000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2000,
    },
    {
        'price': 420000,
        'sqft': 2600,
        'bedrooms': 4,
        'bathrooms': 3.5,
        'neighborhood': 'Suburban',
        'year_built': 2010,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1980,
    },
    {
        'price': 320000,
        'sqft': 2000,
        'bedrooms': 4,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1998,
    },
    {
        'price': 450000,
        'sqft': 2800,
        'bedrooms': 5,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2005,
    },
    {
        'price': 380000,
        'sqft': 2400,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 2002,
    },
    {
        'price': 300000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Urban',
        'year_built': 1992,
    },
    {
        'price': 270000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1975,
    },
    {
        'price': 360000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2001,
    },
    {
        'price': 410000,
        'sqft': 2500,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2012,
    },
    {
        'price': 290000,
        'sqft': 1700,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1996,
    },
    {
        'price': 240000,
        'sqft': 1500,
        'bedrooms': 2,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1985,
    },
    {
        'price': 320000,
        'sqft': 1900,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 1999,
    },
    {
        'price': 370000,
        'sqft': 2300,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2003,
    },
    {
        'price': 260000,
        'sqft': 1700,
        'bedrooms': 2,
        'bathrooms': 1.5,
        'neighborhood': 'Rural',
        'year_built': 1978,
    },
    {
        'price': 335000,
        'sqft': 2100,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 2007,
    },
    {
        'price': 310000,
        'sqft': 2000,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood':"Surburban",
        'year_built': 1997,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1983,
    },
    {
        'price': 400000,
        'sqft': 2500,
        'bedrooms':7, 
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2015,
    }]
res = pd.DataFrame(data)
res
# Out:
#      price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0   250000  1800         3        2.0     Suburban        1995
# 1   350000  2200         4        3.0        Urban        2000
# 2   420000  2600         4        3.5     Suburban        2010
# 3   280000  1600         3        2.0        Rural        1980
# 4   320000  2000         4        2.5     Suburban        1998
# 5   450000  2800         5        3.0        Urban        2005
# 6   380000  2400         3        2.5     Suburban        2002
# 7   300000  1800         3        2.0        Urban        1992
# 8   270000  1600         3        2.0        Rural        1975
# 9   360000  2200         4        3.0     Suburban        2001
# 10  410000  2500         4        3.0        Urban        2012
# 11  290000  1700         3        2.5     Suburban        1996
# 12  240000  1500         2        2.0        Rural        1985
# 13  320000  1900         3        2.5        Urban        1999
# ...

# %%
display(res.head())
# Out:
#     price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0  250000  1800         3        2.0     Suburban        1995
# 1  350000  2200         4        3.0        Urban        2000
# 2  420000  2600         4        3.5     Suburban        2010
# 3  280000  1600         3        2.0        Rural        1980
# 4  320000  2000         4        2.5     Suburban        1998

# %%
display(res.describe())
# Out:
#                price         sqft   bedrooms  bathrooms   year_built
# count      20.000000    20.000000  20.000000  20.000000    20.000000
# mean   329750.000000  2040.000000   3.500000   2.475000  1996.650000
# std     60837.899372   384.433965   1.100239   0.525031    11.412251
# min    240000.000000  1500.000000   2.000000   1.500000  1975.000000
# 25%    280000.000000  1700.000000   3.000000   2.000000  1990.250000
# 50%    320000.000000  2000.000000   3.000000   2.500000  1998.500000
# 75%    372500.000000  2325.000000   4.000000   3.000000  2003.500000
# max    450000.000000  2800.000000   7.000000   3.500000  2015.000000

# %%
display(res.isna().sum())
# Out:
# price           0
# sqft            0
# bedrooms        0
# bathrooms       0
# neighborhood    0
# year_built      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
plt.figure(figsize=(8,2))
sns.histplot(res["bedrooms"],bins=30,kde=True)
plt.title("Histogram of the house price")
plt.xlabel("bedrooms")
plt.ylabel("count")
plt.show()

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
data = [ {
        'price': 250000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Suburban',
        'year_built': 1995,
    },
    {
        'price': 350000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2000,
    },
    {
        'price': 420000,
        'sqft': 2600,
        'bedrooms': 4,
        'bathrooms': 3.5,
        'neighborhood': 'Suburban',
        'year_built': 2010,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1980,
    },
    {
        'price': 320000,
        'sqft': 2000,
        'bedrooms': 4,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1998,
    },
    {
        'price': 450000,
        'sqft': 2800,
        'bedrooms': 5,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2005,
    },
    {
        'price': 380000,
        'sqft': 2400,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 2002,
    },
    {
        'price': 300000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Urban',
        'year_built': 1992,
    },
    {
        'price': 270000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1975,
    },
    {
        'price': 360000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2001,
    },
    {
        'price': 410000,
        'sqft': 2500,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2012,
    },
    {
        'price': 290000,
        'sqft': 1700,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1996,
    },
    {
        'price': 240000,
        'sqft': 1500,
        'bedrooms': 2,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1985,
    },
    {
        'price': 320000,
        'sqft': 1900,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 1999,
    },
    {
        'price': 370000,
        'sqft': 2300,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2003,
    },
    {
        'price': 260000,
        'sqft': 1700,
        'bedrooms': 2,
        'bathrooms': 1.5,
        'neighborhood': 'Rural',
        'year_built': 1978,
    },
    {
        'price': 335000,
        'sqft': 2100,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 2007,
    },
    {
        'price': 310000,
        'sqft': 2000,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood':"Surburban",
        'year_built': 1997,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1983,
    },
    {
        'price': 400000,
        'sqft': 2500,
        'bedrooms':7, 
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2015,
    }]
res = pd.DataFrame(data)
display(res)
display(res.head())
display(res.describe())
display(res.isna().sum())

plt.figure(figsize=(8,2))
sns.histplot(res["bedrooms"],bins=20,kde=True)
plt.xlabel("bedrooms")
plt.ylabel("count")
plt.title("histogram of the bedrooms of the house ")
plt.show()
# Out:
#      price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0   250000  1800         3        2.0     Suburban        1995
# 1   350000  2200         4        3.0        Urban        2000
# 2   420000  2600         4        3.5     Suburban        2010
# 3   280000  1600         3        2.0        Rural        1980
# 4   320000  2000         4        2.5     Suburban        1998
# 5   450000  2800         5        3.0        Urban        2005
# 6   380000  2400         3        2.5     Suburban        2002
# 7   300000  1800         3        2.0        Urban        1992
# 8   270000  1600         3        2.0        Rural        1975
# 9   360000  2200         4        3.0     Suburban        2001
# 10  410000  2500         4        3.0        Urban        2012
# 11  290000  1700         3        2.5     Suburban        1996
# 12  240000  1500         2        2.0        Rural        1985
# 13  320000  1900         3        2.5        Urban        1999
# ...

# %%
display(res.isnull().sum())
# Out:
# price           0
# sqft            0
# bedrooms        0
# bathrooms       0
# neighborhood    0
# year_built      0
# dtype: int64

# %%
import pandas as pd
data = [ {
        'price': 250000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Suburban',
        'year_built': 1995,
    },
    {
        'price': 350000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2000,
    },
    {
        'price': 420000,
        'sqft': 2600,
        'bedrooms': 4,
        'bathrooms': 3.5,
        'neighborhood': 'Suburban',
        'year_built': 2010,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1980,
    },
    {
        'price': 320000,
        'sqft': 2000,
        'bedrooms': 4,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1998,
    },
    {
        'price': 450000,
        'sqft': 2800,
        'bedrooms': 5,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2005,
    },
    {
        'price': 380000,
        'sqft': 2400,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 2002,
    },
    {
        'price': 300000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Urban',
        'year_built': 1992,
    },
    {
        'price': 270000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1975,
    },
    {
        'price': 360000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2001,
    },
    {
        'price': 410000,
        'sqft': 2500,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2012,
    },
    {
        'price': 290000,
        'sqft': 1700,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1996,
    },
    {
        'price': 240000,
        'sqft': 1500,
        'bedrooms': 2,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1985,
    },
    {
        'price': 320000,
        'sqft': 1900,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 1999,
    },
    {
        'price': 370000,
        'sqft': 2300,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2003,
    },
    {
        'price': 260000,
        'sqft': 1700,
        'bedrooms': 2,
        'bathrooms': 1.5,
        'neighborhood': 'Rural',
        'year_built': 1978,
    },
    {
        'price': 335000,
        'sqft': 2100,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 2007,
    },
    {
        'price': 310000,
        'sqft': 2000,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood':"Surburban",
        'year_built': 1997,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1983,
    },
    {
        'price': 400000,
        'sqft': 2500,
        'bedrooms':7, 
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2015,
    }]
res = pd.DataFrame(data)
res
# Out:
#      price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0   250000  1800         3        2.0     Suburban        1995
# 1   350000  2200         4        3.0        Urban        2000
# 2   420000  2600         4        3.5     Suburban        2010
# 3   280000  1600         3        2.0        Rural        1980
# 4   320000  2000         4        2.5     Suburban        1998
# 5   450000  2800         5        3.0        Urban        2005
# 6   380000  2400         3        2.5     Suburban        2002
# 7   300000  1800         3        2.0        Urban        1992
# 8   270000  1600         3        2.0        Rural        1975
# 9   360000  2200         4        3.0     Suburban        2001
# 10  410000  2500         4        3.0        Urban        2012
# 11  290000  1700         3        2.5     Suburban        1996
# 12  240000  1500         2        2.0        Rural        1985
# 13  320000  1900         3        2.5        Urban        1999
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
plt.figure(figsize=(10,2))
plt.subplot(2,2,1)
sns.histplot(res["price"],bins=20,kde=True)
plt.xlabel("price")
plt.ylabel("count")
plt.title("histogram of the house price")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.subplot(2,2,1)
sns.countplot(data = res, x ="price")
plt.xlabel("price")
plt.title("countplot of the house price")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.subplot(2,2,1)
sns.boxplot(data=res,x="price",y="bedrooms")
plt.xlabel("price")
plt.ylabel("bedrooms")
plt.title("boxplot of the house price")
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.subplot(2,2,1)
sns.scatterplot(data = res ,x = "price", y = "bedrooms")
plt.xlabel("price")
plt.ylabel("bedrooms")
plt.title("scatterplot of the house price and bedrooms")
plt.show()

# %%
import pandas as pd
data = [ {
        'price': 250000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Suburban',
        'year_built': 1995,
    },
    {
        'price': 350000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2000,
    },
    {
        'price': 420000,
        'sqft': 2600,
        'bedrooms': 4,
        'bathrooms': 3.5,
        'neighborhood': 'Suburban',
        'year_built': 2010,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1980,
    },
    {
        'price': 320000,
        'sqft': 2000,
        'bedrooms': 4,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1998,
    },
    {
        'price': 450000,
        'sqft': 2800,
        'bedrooms': 5,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2005,
    },
    {
        'price': 380000,
        'sqft': 2400,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 2002,
    },
    {
        'price': 300000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Urban',
        'year_built': 1992,
    },
    {
        'price': 270000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1975,
    },
    {
        'price': 360000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2001,
    },
    {
        'price': 410000,
        'sqft': 2500,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2012,
    },
    {
        'price': 290000,
        'sqft': 1700,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1996,
    },
    {
        'price': 240000,
        'sqft': 1500,
        'bedrooms': 2,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1985,
    },
    {
        'price': 320000,
        'sqft': 1900,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 1999,
    },
    {
        'price': 370000,
        'sqft': 2300,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2003,
    },
    {
        'price': 260000,
        'sqft': 1700,
        'bedrooms': 2,
        'bathrooms': 1.5,
        'neighborhood': 'Rural',
        'year_built': 1978,
    },
    {
        'price': 335000,
        'sqft': 2100,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 2007,
    },
    {
        'price': 310000,
        'sqft': 2000,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood':"Surburban",
        'year_built': 1997,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1983,
    },
    {
        'price': 400000,
        'sqft': 2500,
        'bedrooms':7, 
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2015,
    }]
res = pd.DataFrame(data)
display(res)
# Out:
#      price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0   250000  1800         3        2.0     Suburban        1995
# 1   350000  2200         4        3.0        Urban        2000
# 2   420000  2600         4        3.5     Suburban        2010
# 3   280000  1600         3        2.0        Rural        1980
# 4   320000  2000         4        2.5     Suburban        1998
# 5   450000  2800         5        3.0        Urban        2005
# 6   380000  2400         3        2.5     Suburban        2002
# 7   300000  1800         3        2.0        Urban        1992
# 8   270000  1600         3        2.0        Rural        1975
# 9   360000  2200         4        3.0     Suburban        2001
# 10  410000  2500         4        3.0        Urban        2012
# 11  290000  1700         3        2.5     Suburban        1996
# 12  240000  1500         2        2.0        Rural        1985
# 13  320000  1900         3        2.5        Urban        1999
# ...

# %%
display(res.describe())
display(res.isnull().sum())
display(res.head())
display(res.tail())
# Out:
#                price         sqft   bedrooms  bathrooms   year_built
# count      20.000000    20.000000  20.000000  20.000000    20.000000
# mean   329750.000000  2040.000000   3.500000   2.475000  1996.650000
# std     60837.899372   384.433965   1.100239   0.525031    11.412251
# min    240000.000000  1500.000000   2.000000   1.500000  1975.000000
# 25%    280000.000000  1700.000000   3.000000   2.000000  1990.250000
# 50%    320000.000000  2000.000000   3.000000   2.500000  1998.500000
# 75%    372500.000000  2325.000000   4.000000   3.000000  2003.500000
# max    450000.000000  2800.000000   7.000000   3.500000  2015.000000
# price           0
# sqft            0
# bedrooms        0
# bathrooms       0
# neighborhood    0
# year_built      0
# dtype: int64
#     price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0  250000  1800         3        2.0     Suburban        1995
# 1  350000  2200         4        3.0        Urban        2000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
plt.figure(figsize=(10,2))
plt.subplot(2,2,1)
sns.histplot(res["price"], bins=20 , kde=True)
plt.xlabel("price")
plt.ylabel("count")
plt.title("histogram of the house price")
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.subplot(2,2,1)
sns.countplot(data=res, x = "price" )
plt.xlabel("price")
plt.ylabel("bedrooms")
plt.title("countplot of the house price")
plt.show()

# %%
plt.figure(figsize=(8,2))
plt.subplot(2,2,1)
sns.boxplot(data = res , x = "price" , y = "bedrooms")
plt.xlabel("price")
plt.ylabel("bedrooms")
plt.title("boxplot of the price and bedrooms")
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(2,2,1)
sns.scatterplot(data = res , x = "price", y = "bedrooms")
plt.xlabel("price")
plt.ylabel("bedrooms")
plt.title("scatterplot of the price and bedrooms")
plt.show()

# %%
import pandas as pd
age = [20,30,40,50,60]
bins = [11,22,33,44,55]
res = pd.cut(age,bins=bins)
res
# Out:
# [(11.0, 22.0], (22.0, 33.0], (33.0, 44.0], (44.0, 55.0], NaN]
# Categories (4, interval[int64, right]): [(11, 22] < (22, 33] < (33, 44] < (44, 55]]

# %%
import pandas as pd
score = [20,30,40,50,60]
res = pd.qcut(score,q=3)
res
# Out:
# [(19.999, 33.333], (19.999, 33.333], (33.333, 46.667], (46.667, 60.0], (46.667, 60.0]]
# Categories (3, interval[float64, right]): [(19.999, 33.333] < (33.333, 46.667] < (46.667, 60.0]]

# %%
import pandas as pd
age = [10,20,30,40,50]
res = pd.qcut(age, q=3)
res
# Out:
# [(9.999, 23.333], (9.999, 23.333], (23.333, 36.667], (36.667, 50.0], (36.667, 50.0]]
# Categories (3, interval[float64, right]): [(9.999, 23.333] < (23.333, 36.667] < (36.667, 50.0]]

# %%
import pandas as pd
age = [20,30,40,50,60]
bins = [11,22,33,44,55]
res = pd.cut(age,bins=bins)
res
# Out:
# [(11.0, 22.0], (22.0, 33.0], (33.0, 44.0], (44.0, 55.0], NaN]
# Categories (4, interval[int64, right]): [(11, 22] < (22, 33] < (33, 44] < (44, 55]]

# %%
import pandas as pd
data = {
    "name":["alex","pooja","kumar","shivam","neha"],
    "age":[20,30,40,50,60]
}
res = pd.DataFrame(data)
res
# Out:
#      name  age
# 0    alex   20
# 1   pooja   30
# 2   kumar   40
# 3  shivam   50
# 4    neha   60

# %%
quans = [0,0.5,0.9,1.0]
res["Performance"] = pd.qcut(res["age"],q=quans,labels=("poor","good","average"))
display(res)
# Out:
#      name  age Performance
# 0    alex   20        poor
# 1   pooja   30        poor
# 2   kumar   40        poor
# 3  shivam   50        good
# 4    neha   60     average

# %%
import pandas as pd
data = [ {
        'price': 250000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Suburban',
        'year_built': 1995,
    },
    {
        'price': 350000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2000,
    },
    {
        'price': 420000,
        'sqft': 2600,
        'bedrooms': 4,
        'bathrooms': 3.5,
        'neighborhood': 'Suburban',
        'year_built': 2010,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1980,
    },
    {
        'price': 320000,
        'sqft': 2000,
        'bedrooms': 4,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1998,
    },
    {
        'price': 450000,
        'sqft': 2800,
        'bedrooms': 5,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2005,
    },
    {
        'price': 380000,
        'sqft': 2400,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 2002,
    },
    {
        'price': 300000,
        'sqft': 1800,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Urban',
        'year_built': 1992,
    },
    {
        'price': 270000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1975,
    },
    {
        'price': 360000,
        'sqft': 2200,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2001,
    },
    {
        'price': 410000,
        'sqft': 2500,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2012,
    },
    {
        'price': 290000,
        'sqft': 1700,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Suburban',
        'year_built': 1996,
    },
    {
        'price': 240000,
        'sqft': 1500,
        'bedrooms': 2,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1985,
    },
    {
        'price': 320000,
        'sqft': 1900,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 1999,
    },
    {
        'price': 370000,
        'sqft': 2300,
        'bedrooms': 4,
        'bathrooms': 3,
        'neighborhood': 'Suburban',
        'year_built': 2003,
    },
    {
        'price': 260000,
        'sqft': 1700,
        'bedrooms': 2,
        'bathrooms': 1.5,
        'neighborhood': 'Rural',
        'year_built': 1978,
    },
    {
        'price': 335000,
        'sqft': 2100,
        'bedrooms': 3,
        'bathrooms': 2.5,
        'neighborhood': 'Urban',
        'year_built': 2007,
    },
    {
        'price': 310000,
        'sqft': 2000,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood':"Surburban",
        'year_built': 1997,
    },
    {
        'price': 280000,
        'sqft': 1600,
        'bedrooms': 3,
        'bathrooms': 2,
        'neighborhood': 'Rural',
        'year_built': 1983,
    },
    {
        'price': 400000,
        'sqft': 2500,
        'bedrooms':7, 
        'bathrooms': 3,
        'neighborhood': 'Urban',
        'year_built': 2015,
    }]
res = pd.DataFrame(data)
res
# Out:
#      price  sqft  bedrooms  bathrooms neighborhood  year_built
# 0   250000  1800         3        2.0     Suburban        1995
# 1   350000  2200         4        3.0        Urban        2000
# 2   420000  2600         4        3.5     Suburban        2010
# 3   280000  1600         3        2.0        Rural        1980
# 4   320000  2000         4        2.5     Suburban        1998
# 5   450000  2800         5        3.0        Urban        2005
# 6   380000  2400         3        2.5     Suburban        2002
# 7   300000  1800         3        2.0        Urban        1992
# 8   270000  1600         3        2.0        Rural        1975
# 9   360000  2200         4        3.0     Suburban        2001
# 10  410000  2500         4        3.0        Urban        2012
# 11  290000  1700         3        2.5     Suburban        1996
# 12  240000  1500         2        2.0        Rural        1985
# 13  320000  1900         3        2.5        Urban        1999
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
plt.figure(figsize=(10,2))
plt.subplot(2,2,3)
sns.histplot(res["bedrooms"],bins=10,kde=True)
plt.xlabel("bedrooms")
plt.ylabel("counts")
plt.title("histogram of the house bedrooms" )
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,2))
plt.subplot(2,2,1)
sns.countplot(data = res, x = "price")
plt.show()

# %%
sns.boxplot(data=res,x="price",y="bedrooms")
plt.show()

# %%
sns.scatterplot(data=res, x="price", y = "bedrooms")
plt.show()

# %%
import pandas as pd
age = [20,30,40,50,60]
bins = [11,22,33,44,55]
res = pd.cut(age,bins=bins)
res
# Out:
# [(11.0, 22.0], (22.0, 33.0], (33.0, 44.0], (44.0, 55.0], NaN]
# Categories (4, interval[int64, right]): [(11, 22] < (22, 33] < (33, 44] < (44, 55]]

# %%
import pandas as pd
score = [20,30,40,50,60]
res = pd.qcut(score, q=3)
res
# Out:
# [(19.999, 33.333], (19.999, 33.333], (33.333, 46.667], (46.667, 60.0], (46.667, 60.0]]
# Categories (3, interval[float64, right]): [(19.999, 33.333] < (33.333, 46.667] < (46.667, 60.0]]

# %%
import pandas as pd
data = {
    "name":["alex","pooja","sita","neha","lion"],
    "age":[20,30,40,50,60]
}
res = pd.DataFrame(data)
res
# Out:
#     name  age
# 0   alex   20
# 1  pooja   30
# 2   sita   40
# 3   neha   50
# 4   lion   60

# %%
quans = [0,0.5,0.9,1.0]
res["performance"] = pd.qcut(res["age"],q=quans,labels = ("poor","good","average"))
res
# Out:
#     name  age performance
# 0   alex   20        poor
# 1  pooja   30        poor
# 2   sita   40        poor
# 3   neha   50        good
# 4   lion   60     average

# %%
import nltk 
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")
nltk.download("maxent_ne_chunker")
nltk.download("word")
from nltk.tokenize import word_tokenize
from nltk import pos_tag,ne_chunk
s= "Apple Inc. was founded by Steve Jobs in Cupertino, California, on April 1, 1976."
w = word_tokenize(s)
p = pos_tag(w)
n = ne_chunk(p)
print(n)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Error loading word: Package 'word' not found in index
# (S
#   (PERSON Apple/NNP)
#   (ORGANIZATION Inc./NNP)
#   was/VBD
#   founded/VBN
#   by/IN
#   (PERSON Steve/NNP Jobs/NNP)
#   in/IN
#   (GPE Cupertino/NNP)
#   ,/,
#   (GPE California/NNP)
#   ,/,
#   on/IN
#   April/NNP
#   1/CD
#   ,/,
#   1976/CD
#   ./.)

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import nltk
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")
nltk.download("maxent_ne_chunker")
nltk.download("word")
from nltk.tokenize import word_tokenize
from nltk import pos_tag,ne_chunk
s= "Apple Inc. was founded by Steve Jobs in Cupertino, California, on April 1, 1976."
w = word_tokenize(s)
p = pos_tag(w)
n = ne_chunk(p)
print(n)
# Out:
# (S
#   (PERSON Apple/NNP)
#   (ORGANIZATION Inc./NNP)
#   was/VBD
#   founded/VBN
#   by/IN
#   (PERSON Steve/NNP Jobs/NNP)
#   in/IN
#   (GPE Cupertino/NNP)
#   ,/,
#   (GPE California/NNP)
#   ,/,
#   on/IN
#   April/NNP
#   1/CD
#   ,/,
#   1976/CD
#   ./.)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Error loading word: Package 'word' not found in index

# %%
import nltk
nltk.download("punkt")
from nltk.tokenize import word_tokenize
s= "Apple Inc. was founded by Steve Jobs in Cupertino, California, on April 1, 1976."
w = word_tokenize(s)
print(w)
# Out:
# ['Apple', 'Inc.', 'was', 'founded', 'by', 'Steve', 'Jobs', 'in', 'Cupertino', ',', 'California', ',', 'on', 'April', '1', ',', '1976', '.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk 
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")
from nltk.tokenize import word_tokenize
from nltk import pos_tag
s= "Apple Inc. was founded by Steve Jobs in Cupertino, California, on April 1, 1976."
w = word_tokenize(s)
p = pos_tag(w)
print(p)
# Out:
# [('Apple', 'NNP'), ('Inc.', 'NNP'), ('was', 'VBD'), ('founded', 'VBN'), ('by', 'IN'), ('Steve', 'NNP'), ('Jobs', 'NNP'), ('in', 'IN'), ('Cupertino', 'NNP'), (',', ','), ('California', 'NNP'), (',', ','), ('on', 'IN'), ('April', 'NNP'), ('1', 'CD'), (',', ','), ('1976', 'CD'), ('.', '.')]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
